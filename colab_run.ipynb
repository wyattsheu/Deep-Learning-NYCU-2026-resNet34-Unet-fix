# %%
# 1. 從你的 GitHub 複製專案
# %cd /content
# !git clone https://github.com/wyattsheu/Deep-Learning-NYCU-2026-resNet34-Unet.git

# 2. 切換工作目錄到 Lab2
# %cd Deep-Learning-NYCU-2026-resNet34-Unet/Lab2
  
# 檢查一下是不是成功進來了 (應該要看到 src, requirements.txt 等檔案)
# !ls

# !export HF_TOKEN=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
# Out:
# Cloning into 'Deep-Learning-NYCU-2026'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# ^Cceiving objects:  35% (12/34), 1.92 MiB | 1.25 MiB/s
# [Errno 2] No such file or directory: 'Deep-Learning-NYCU-2026/Lab2'
# /content/Deep-Learning-NYCU-2026/Lab2
# colab_run.ipynb  Lab2_Binary_Semantic_Segmentation_2026_Spring.pdf  src
# dataset		 requirements.txt

# %%
# 根據你的 requirements.txt 安裝套件
# %pip install -r requirements.txt

# %%
# 執行你的訓練主程式
# !python3 src./train.py
# !python3 src/train.py --epochs 70 --batch_size 24 --learning_rate 0.0001 --model_type ResNet34_UNet or UNet
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/Resources/Python.app/Contents/MacOS/Python: can't open file '/Users/wyattsheu/Downloads/Deep-Learning-NYCU-2026/Lab2/src./train.py': [Errno 2] No such file or directory

# %%
# # 1. 確保同步遠端最新狀態
# !git fetch origin

# # 2. 強制將本地分支重設為遠端的 main 分支
# !git reset --hard origin/main
# Out:
# HEAD is now at 3ff27a2 Initial commit: Add Lab0, Lab1, and Lab2 (U-Net Semantic Segmentation)

# %%
# !ls
# Out:
# colab_run.ipynb  Lab2_Binary_Semantic_Segmentation_2026_Spring.pdf  src
# dataset		 requirements.txt

# %%
# !cd C:\Users\USER\Downloads\強化34UNET\Deep-Learning-NYCU-2026-resNet34-Unet

# %%
# !dir
# Out:
#  �Ϻа� C �����ϺЬO Windows-SSD
#  �ϺаϧǸ�:  D813-A8D9
#
#  c:\Users\USER\Downloads\�j��34UNET\Deep-Learning-NYCU-2026-resNet34-Unet ���ؿ�
#
# 2026/03/23  �W�� 12:31    <DIR>          .
# 2026/03/23  �W�� 12:20    <DIR>          ..
# 2026/03/23  �W�� 12:20               885 .gitignore
# 2026/03/23  �W�� 12:25    <DIR>          .venv
# 2026/03/23  �W�� 01:22             7,969 colab_run.ipynb
# 2026/03/23  �W�� 12:33    <DIR>          dataset
# 2026/03/23  �W�� 12:20           872,134 Lab2_Binary_Semantic_Segmentation_2026_Spring.pdf
# 2026/03/23  �W�� 12:20                41 README.md
# 2026/03/23  �W�� 12:37               161 requirements.txt
# 2026/03/23  �W�� 12:55    <DIR>          saved_models
# 2026/03/23  �W�� 12:31    <DIR>          src
#                5 ���ɮ�         881,190 �줸��
#                6 �ӥؿ�  31,035,883,520 �줸�եi��

# %%
# !python src\train.py --epochs 70 --batch_size 24 --learning_rate 0.0001 --model_type ResNet34_UNet
# Out:
# ^C
# ...
# Epoch 1/70:   9%|▉         | 20/216 [00:26<00:27,  7.06it/s, Loss=0.4621]
# 使用本地資料夾: c:\Users\USER\Downloads\強化34UNET\Deep-Learning-NYCU-2026-resNet34-Unet\dataset\oxford-iiit-pet
# 使用本地資料夾: c:\Users\USER\Downloads\強化34UNET\Deep-Learning-NYCU-2026-resNet34-Unet\dataset\oxford-iiit-pet
# device: cuda
# training by ResNet34_UNet model
# batch size: 24

# %%
python src\train.py --epochs 75 --batch_size 24 --learning_rate 0.0001 --max_lr_mult 5 --model_type ResNet34_UNet
python src\train.py --epochs 50 --batch_size 4 --learning_rate 0.0001 --max_lr_mult 5 --model_type UNet
